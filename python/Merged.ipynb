# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression

# %%
df  = pd.read_csv('bs1.csv')
df1 = pd.read_csv('h1.csv')
df2 = pd.read_csv('d1.csv')

# %%
merged_df = pd.concat([df, df1, df2], axis=1)

# %%
merged_df
# Out:
#        bmi  brh_disease   age smoking_status  avg_glucose_level  hypertension  \
# 0     19.7          0.0  20.0         smokes              84.62           0.0
# 1     34.1          0.0  20.0   never smoked              96.57           0.0
# 2     28.1          0.0  20.0   never smoked              91.60           0.0
# 3     26.2          0.0  20.0        Unknown              98.70           0.0
# 4     21.7          0.0  20.0   never smoked             104.48           0.0
# ...    ...          ...   ...            ...                ...           ...
# 4521   NaN          NaN   NaN            NaN                NaN           NaN
# 4522   NaN          NaN   NaN            NaN                NaN           NaN
# 4523   NaN          NaN   NaN            NaN                NaN           NaN
# 4524   NaN          NaN   NaN            NaN                NaN           NaN
# 4525   NaN          NaN   NaN            NaN                NaN           NaN
#
# ...

# %%
merged_df.isna().sum()
# Out:
# bmi                  532
# brh_disease          532
# age                  532
# smoking_status       532
# avg_glucose_level    532
# hypertension         532
# stroke               532
# HeartDisease         150
# heartstroke          150
# DiffWalking          150
# PhysicalHealth       150
# KidneyDisease        150
# diabetes               0
# HbA1c_level            0
# dtype: int64

# %%
merged_df.dropna(inplace=True)

# %%
len(merged_df)
# Out:
# 3994

# %% [markdown]
# # BRAIN STROKE

# %%
le=LabelEncoder()
list=['smoking_status']
for i in list:
    merged_df[i]=le.fit_transform(df[i])

# %%
X = merged_df.drop(['HeartDisease', 'heartstroke','DiffWalking', 'PhysicalHealth','KidneyDisease','diabetes','HbA1c_level'],axis=1)
y =merged_df['stroke']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1121
#          1.0       1.00      1.00      1.00        78
#
#     accuracy                           1.00      1199
#    macro avg       1.00      1.00      1.00      1199
# weighted avg       1.00      1.00      1.00      1199

# %% [markdown]
# # DIABETES

# %%
le=LabelEncoder()
list=['smoking_status']
for i in list:
    merged_df[i]=le.fit_transform(df[i])

# %%
X = merged_df.drop([ 'stroke','DiffWalking', 'PhysicalHealth','KidneyDisease','HbA1c_level','heartstroke'],axis=1)
y = merged_df['diabetes']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       657
#            1       1.00      1.00      1.00       542
#
#     accuracy                           1.00      1199
#    macro avg       1.00      1.00      1.00      1199
# weighted avg       1.00      1.00      1.00      1199

# %%
merged_df.to_csv(merged_df.to_excel(r'D:\Final Project\merged_df.xlsx', index=False))
# Out:
# ',bmi,brh_disease,age,smoking_status,avg_glucose_level,hypertension,stroke,HeartDisease,heartstroke,DiffWalking,PhysicalHealth,KidneyDisease,diabetes,HbA1c_level\r\n0,19.7,0.0,20.0,3,84.62,0.0,0.0,1.0,No,No,0.0,No,1,6.1\r\n1,34.1,0.0,20.0,2,96.57,0.0,0.0,1.0,No,No,0.0,No,1,6.2\r\n2,28.1,0.0,20.0,2,91.6,0.0,0.0,1.0,Yes,No,20.0,No,1,8.2\r\n3,26.2,0.0,20.0,0,98.7,0.0,0.0,1.0,Yes,No,0.0,Yes,1,6.6\r\n4,21.7,0.0,20.0,2,104.48,0.0,0.0,1.0,No,No,0.0,No,1,5.8\r\n5,31.0,0.0,20.0,0,127.18,0.0,0.0,1.0,No,No,0.0,No,1,6.6\r\n6,20.8,0.0,20.0,2,73.0,0.0,0.0,1.0,No,No,0.0,No,1,6.6\r\n7,20.4,0.0,20.0,2,55.25,0.0,0.0,1.0,No,No,0.0,No,0,3.5\r\n8,22.3,0.0,20.0,2,74.02,0.0,0.0,1.0,No,No,0.0,No,0,6.2\r\n9,41.2,0.0,20.0,2,79.08,0.0,0.0,1.0,No,Yes,30.0,No,0,3.5\r\n10,27.5,0.0,20.0,2,184.25,0.0,0.0,1.0,No,No,0.0,No,0,6.0\r\n11,27.9,0.0,20.0,1,106.97,0.0,0.0,1.0,No,No,0.0,No,0,5.8\r\n12,27.5,0.0,20.0,2,112.96,0.0,0.0,1.0,Yes,No,3.0,Yes,0,3.5\r\n13,20.6,0.0,20.0,3,76.34,0.0,0.0,1.0,No,No,0.0,No,0,5.8\r\n14,27.8
# ...

# %% [markdown]
# # HEART

# %%
le=LabelEncoder()
list=['smoking_status','DiffWalking','KidneyDisease']
for i in list:
    merged_df[i]=le.fit_transform(merged_df[i])

# %%
X = merged_df.drop([ 'brh_disease','avg_glucose_level', 'hypertension','HbA1c_level','heartstroke'],axis=1)
y = merged_df['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       637
#          1.0       1.00      1.00      1.00       562
#
#     accuracy                           1.00      1199
#    macro avg       1.00      1.00      1.00      1199
# weighted avg       1.00      1.00      1.00      1199
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
